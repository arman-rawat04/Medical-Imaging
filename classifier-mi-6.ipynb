# %%
import torch
import tensorflow as tf

device=torch.device("cuda" if torch.cuda.is_available() else 'cpu')
print(device)
# Optional: Force GPU/CPU usage
if tf.config.list_physical_devices('GPU'):
    device = '/GPU:0'
    print("Using GPU")
else:
    device = '/CPU:0'
    print("Using CPU")

import torch
import tensorflow as tf

device=torch.device("cuda" if torch.cuda.is_available() else 'cpu')
print(device)
# Optional: Force GPU/CPU usage
if tf.config.list_physical_devices('GPU'):
    device = '/GPU:0'
    print("Using GPU")
else:
    device = '/CPU:0'
    print("Using CPU")


import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# Load your data
X_train = np.load('/kaggle/input/classifier-data/X_train.npy')
y_train_raw = np.load('/kaggle/input/classifier-data/y_train.npy')
X_test = np.load('/kaggle/input/classifier-data/X_test.npy')
y_test_raw = np.load('/kaggle/input/classifier-data/y_test.npy')

# Convert y to binary labels: 1 for MI, 0 for non-MI
y_train = (y_train_raw.sum(axis=1) > 0).astype(int)
y_test = (y_test_raw.sum(axis=1) > 0).astype(int)

# Feature scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Define ANN model
model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train_scaled.shape[1],)),
    Dropout(0.4),
    Dense(64, activation='relu'),
    Dropout(0.4),
    Dense(1, activation='sigmoid')  # Sigmoid for binary classification
])

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Early stopping to prevent overfitting
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = model.fit(
    X_train_scaled, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=16,
    callbacks=[early_stop],
    verbose=1
)

# Predict on test set
y_pred_probs = model.predict(X_test_scaled)
y_pred = (y_pred_probs > 0.5).astype(int)

# Evaluation
print("Accuracy:", accuracy_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# cuda
# Using GPU
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 260ms/step - accuracy: 0.5864 - loss: 0.8381 - val_accuracy: 0.7308 - val_loss: 0.6318
# Epoch 2/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5981 - loss: 0.8175 - val_accuracy: 0.6923 - val_loss: 0.6309
# Epoch 3/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6357 - loss: 0.6060 - val_accuracy: 0.6538 - val_loss: 0.5730
# Epoch 4/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7465 - loss: 0.4668 - val_accuracy: 0.6923 - val_loss: 0.5450
# Epoch 5/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7446 - loss: 0.6060 - val_accuracy: 0.6538 - val_loss: 0.5339
# Epoch 6/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8447 - loss: 0.4726 - val_accuracy: 0.7308 - val_loss: 0.5152
# Epoch 7/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8330 - loss: 0.3610 - val_accuracy: 0.7692 - val_loss: 0.5286
# Epoch 8/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8399 - loss: 0.3367 - val_accuracy: 0.7692 - val_loss: 0.5299
# Epoch 9/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9080 - loss: 0.2871 - val_accuracy: 0.8077 - val_loss: 0.5174
# Epoch 10/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9106 - loss: 0.2734 - val_accuracy: 0.8077 - val_loss: 0.5148
# Epoch 11/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9236 - loss: 0.2332 - val_accuracy: 0.8077 - val_loss: 0.5298
# Epoch 12/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9094 - loss: 0.2410 - val_accuracy: 0.7692 - val_loss: 0.5334
# Epoch 13/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9311 - loss: 0.2285 - val_accuracy: 0.7308 - val_loss: 0.5416
# Epoch 14/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9631 - loss: 0.1741 - val_accuracy: 0.6923 - val_loss: 0.5684
# Epoch 15/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9686 - loss: 0.1609 - val_accuracy: 0.6923 - val_loss: 0.5575
# Epoch 16/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9507 - loss: 0.1857 - val_accuracy: 0.6538 - val_loss: 0.5021
# Epoch 17/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9789 - loss: 0.1189 - val_accuracy: 0.7308 - val_loss: 0.4881
# Epoch 18/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9883 - loss: 0.1068 - val_accuracy: 0.7308 - val_loss: 0.4971
# Epoch 19/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9575 - loss: 0.1193 - val_accuracy: 0.7308 - val_loss: 0.5319
# Epoch 20/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9863 - loss: 0.1114 - val_accuracy: 0.6923 - val_loss: 0.5777
# Epoch 21/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9346 - loss: 0.1502 - val_accuracy: 0.6923 - val_loss: 0.6280
# Epoch 22/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9784 - loss: 0.0754 - val_accuracy: 0.6538 - val_loss: 0.6604
# Epoch 23/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9724 - loss: 0.0981 - val_accuracy: 0.6538 - val_loss: 0.6480
# Epoch 24/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9793 - loss: 0.1097 - val_accuracy: 0.6538 - val_loss: 0.6353
# Epoch 25/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0563 - val_accuracy: 0.6923 - val_loss: 0.6414
# Epoch 26/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0856 - val_accuracy: 0.6923 - val_loss: 0.6381
# Epoch 27/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9572 - loss: 0.1152 - val_accuracy: 0.6923 - val_loss: 0.6408
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# Accuracy: 0.696969696969697
# F1 Score: 0.7222222222222223
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.77      0.59      0.67        17
#            1       0.65      0.81      0.72        16
#
#     accuracy                           0.70        33
#    macro avg       0.71      0.70      0.69        33
# weighted avg       0.71      0.70      0.69        33
#
# Confusion Matrix:
#  [[10  7]
#  [ 3 13]]
